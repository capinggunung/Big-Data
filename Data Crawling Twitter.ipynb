# %%
import sys
# !{sys.executable} -m pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (1.12.0)
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.2.0 tweepy-3.8.0

# %%
import tweepy

# setting key and token
consumer_key = "********************"
consumer_secret = "*********************************"
access_token = "***************************"
access_token_secret = "*************************"

# %% [markdown]
# <b>Bagi yang belum punya keys dan token dari twitter, bisa daftar dulu di https://developer.twitter.com dan tentunya sudah punya akun twitter</b>

# %%
# membuat object authentication ke API Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# mensetting access token and secret key
auth.set_access_token(access_token, access_token_secret)
# melakukan authentication ke Twitter API
api = tweepy.API(auth)

# %%
# melakukan crawling ke semua data public di home timeline
public_tweets = api.home_timeline()

for tweets in public_tweets:
    print(tweets.text)
# Out:
# #NP  @maroon5 - Daylight #RIAHITSMANCA
# Huawei Nova 5T Banting Harga, Makin Murah Dengan Harga Rp 5 Jutaan https://t.co/LbB4AHbMRj https://t.co/FJ1IMOmFqV
# Lorenzo joins the 200 MotoGP club
#
# Full story 👉 https://t.co/q8osqyA4Dh
#
# #MotoGP
# Halo OtoScreenMax - Mobil Rp 3,8 Miliar Airlangga Hartarto, dari Jaguar sampai Innova https://t.co/FYcqJEOK0Z https://t.co/N45tkH4okJ
# Rektor dan Segenap Sivitas Akademika Universitas Sebelas Maret (UNS) Surakarta menyampaikan Terima kasih kepada TNI… https://t.co/b1WHXYiRnW
# Asiiik, Samsung Galaxy M30s Siap Melenggang Di Pasaran https://t.co/TTotP0Nk8a https://t.co/jEgkd523Wh
# #NP @theweeknd Ft. @DaftPunkUnchd - I feel it coming #RIAHITSMANCA
# #NP @TheChainsmokers - Closer #RIAHITSMANCA
# RT @CRASH_NET_F1: Video: Latest music act announced for @COTA F1 weekend!
#
# More 👉 https://t.co/0W1VD98pw7 #F1 #USGP
# RT @urcherryslurpee: ku colok mata kao https://t.co/n4htO8WrDk
# #NP @Meghan_Trainor - Dear Future Husband #RIAHITSMANCA
# Lagu Manca apa yang lagi Anda sukai?
# reply in RIA HITS MANCA dengan @Imay_FA #RIAHITSMANCA
# #Samsung plans to release a patch for its phones’ in-display fingerprint sensors after reports emerged that the bio… https://t.co/qUwcMjzTQM
# Nggak papa, Pak. Pasang aja foto lama Pak Harto sama Pak Try Sutrisno. Kondisi pemerintahannya nggak jauh beda, kok. https://t.co/n43pv8YB9o
# Our CEO, Fred Diaz, executes the strategy behind the company’s reinvention in the U.S., while still making family a… https://t.co/cvVVrmqVRX
# RT @ahmdtaufiq22: Orang lain punya pendapat, tapi kita adalah decision maker dalam hidup kita sendiri - @AgusMagelangan
#
# @BukuMojok https:…
# RT @BrianHonan: Great to see this transparency from @jayabaloo and @avast_antivirus This is a good read and we all can learn from it https:…
# RT @campuscodi: Avast apparently let the hackers roam around for two weeks to track their movements on purpose.
#
# Talk about keeping your co…

# %%
#melihat struktur JSON sebuah data tweet
public_tweets[0]._json
# Out:
# {'created_at': 'Mon Oct 21 16:00:24 +0000 2019',
#  'id': 1186311279356628995,
#  'id_str': '1186311279356628995',
#  'text': 'Rule #1: Try not to provoke the mother spider. Well, this didn’t go as planned. https://t.co/WMhIcBCVRI',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 1186311195474694144,
#     'id_str': '1186311195474694144',
#     'indices': [80, 103],
#     'media_url': 'http://pbs.twimg.com/media/EHaf0P2XkAIdytu.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/EHaf0P2XkAIdytu.jpg',
#     'url': 'https://t.co/WMhIcBCVRI',
#     'display_url': 'pic.twitter.com/WMhIcBCVRI',
#     'expanded_url': 'https://twitter.com/Honda/status/1186311279356628995/video/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#      'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1186311195474694144,
#     'id_str': '1186311195474694144',
#     'indices': [80, 103],
#     'media_url': 'http://pbs.twimg.com/media/EHaf0P2XkAIdytu.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/EHaf0P2XkAIdytu.jpg',
#     'url': 'https://t.co/WMhIcBCVRI',
#     'display_url': 'pic.twitter.com/WMhIcBCVRI',
#     'expanded_url': 'https://twitter.com/Honda/status/1186311279356628995/video/1',
#     'type': 'video',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#      'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}},
#     'video_info': {'aspect_ratio': [1, 1],
#      'duration_millis': 11375,
#      'variants': [{'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1186311195474694144/pu/vid/480x480/nBF2A060FOqaRclf.mp4?tag=10'},
#       {'bitrate': 432000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1186311195474694144/pu/vid/320x320/gH5x3iL079YNx9ic.mp4?tag=10'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/1186311195474694144/pu/pl/vjjwn-CoNp3dLROu.m3u8?tag=10'},
#       {'bitrate': 1280000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1186311195474694144/pu/vid/720x720/k4S5d0DkX2bJETrX.mp4?tag=10'}]},
#     'additional_media_info': {'monetizable': False}}]},
#  'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 43430484,
#   'id_str': '43430484',
#   'name': 'Honda',
#   'screen_name': 'Honda',
#   'location': 'Torrance, CA',
#   'description': 'Honda is committed to Safety for Everyone™. When designing our vehicles, we think about more than just the occupant’s safety but all road users.',
#   'url': 'https://t.co/8uAr0uCIDx',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8uAr0uCIDx',
#       'expanded_url': 'https://automobiles.honda.com',
#       'display_url': 'automobiles.honda.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 994968,
#   'friends_count': 1581,
#   'listed_count': 3918,
#   'created_at': 'Fri May 29 23:04:30 +0000 2009',
#   'favourites_count': 7965,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 202823,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '9AE4E8',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1145731650296274950/lBoX0UHJ_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1145731650296274950/lBoX0UHJ_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43430484/1569258230',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 3,
#  'favorite_count': 9,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'lang': 'en'}

# %%
# melakukan crawling 10 data public di home timeline 
for tweet in tweepy.Cursor(api.home_timeline).items(10):
    print(tweet.text)
# Out:
# Rule #1: Try not to provoke the mother spider. Well, this didn’t go as planned. https://t.co/WMhIcBCVRI
# #NP BEYONCE - If I Were A Boy #RIAHITSMANCA
# Ada Bug GPS, Apple Peringkatkan Pentingnya Update OS iPhone dan iPad Jadul https://t.co/vY5KCszW2Y
# #NP  @maroon5 - Daylight #RIAHITSMANCA
# Huawei Nova 5T Banting Harga, Makin Murah Dengan Harga Rp 5 Jutaan https://t.co/LbB4AHbMRj https://t.co/FJ1IMOmFqV
# Lorenzo joins the 200 MotoGP club
#
# Full story 👉 https://t.co/q8osqyA4Dh
#
# #MotoGP
# Halo OtoScreenMax - Mobil Rp 3,8 Miliar Airlangga Hartarto, dari Jaguar sampai Innova https://t.co/FYcqJEOK0Z https://t.co/N45tkH4okJ
# Rektor dan Segenap Sivitas Akademika Universitas Sebelas Maret (UNS) Surakarta menyampaikan Terima kasih kepada TNI… https://t.co/b1WHXYiRnW
# Asiiik, Samsung Galaxy M30s Siap Melenggang Di Pasaran https://t.co/TTotP0Nk8a https://t.co/jEgkd523Wh
# #NP @theweeknd Ft. @DaftPunkUnchd - I feel it coming #RIAHITSMANCA

# %%
# menampilkan nama-nama friends
for friend in tweepy.Cursor(api.friends).items():
    print(friend.name)
# Out:
# Raisa Andriana
# Polresta Bogor Kota
# welovehonda
# CRASH.NET/MotoGP
# Crash.Net
# ASTRA MOTOR
# BINUS CAREER
# exwan sugiyanto
# BINUS UNIVERSITY
# CBR.RIDERS.CLUB.SOLO
# Ryant sinevenings
# SragenUnivExpo 2020
# #SalingSapaSRAGEN
# Sagi G
# YouTube Creators
# YouTube
# Deden IM
# fardhianzaenal
# Asosiasi Honda CBR
# SoulKitchen Kemang
# Sheila On 7
# Aleix Espargaró
# Elex Media Komputindo
# Gramedia Store
# Nat Geo Indonesia
# GramediaPustakaUtama
# 98,8 RIA FM SOLO
# Onno W. Purbo
# OFFICIAL BSI TV
# Jeffrey Polnaja
# HL MOTOGP🏁🇪🇸
# R
# Agus Mulyadi
# Irvan Mubarock
# Instagram
# Kompas Ekonomi
# Muhamadfaisal
# sherli_syahputra
# nurwika elasari
# HCRC Banten
# irmawan
# BINUSOnlineLearning
# Honda Community
# Ayuka Suka-Suka^
# Erafone
# Anisa Putri Cahyani
# arq salwa
# CBR Riders BEKASI
# IkhwanulMuslimah
# ILHAM
# Tri Mujiyanto
# ||ojo||fujita||
# muh kurniawan arif m
# ratna rosidah l oci
# Giyan Ayu Wulandari
# Tina Muktiana
# Linanda
# Maya Juwita
# Erwan Amir
# Aziz Cahya Pradana
# Ridwan Ramdhani
# putri lucky
# Honda Bikers Day
# Agung Nugroho
# Romdhoni Hamzah
# adi suryadi
# purnama shiddiq
# ferdys parker
# Adhiyana
# Rhinovall
# IG: moduskeras
# Danny Choo
# Andy_Lutchu
# DR tikect
# Aji Eka Setya Purnam
# ☂ Abub Ener ☂
# Pantau Mudik
# Pria rasa coklat
# Hasto Boedijanto
# zakaria ibra
# Adit THE KING
# Robi Gunawan
# ERLANGGA
# hakiki
# M_Fixer
# Rasyid Riyadi
# Muhammad Rizki TP
# Erbi Setiawan
# Honda CBR Rider Solo
# CBR Riders Jakarta
# CBR Bogor Riders
# habib
# reza andrea
# Tia Febriani
# Lowongan Kerja
# Dwi Cahyono
# Fakikh Saifurrakhim
# Fristian Prasetyo A
# U H W
# Gemal D.Soedaryo
# Anak Ragil
# S. B. Yudhoyono
# Keluarga Ertiga
# Official Suzuki Indonesia
# Asli Enak Trans7
# Bike2Work Indonesia
# UNS Official
# BSI
# Joko Widodo
# Vima L Fadzillah
# Rose
# Avast
# Muhammad Z
# Leon Camier
# Zak
# Sitrek
# Words Motivation
# p_jret (sang bandit)
# Joened Passco
# aldy
# otoscreenmax
# MB Club Indonesia
# Kamiya Riya
# Muhamad Zulkifli
# #KOTASOLO
# BMW Indonesia
# Awalinda Jana Imani
# Chicii
# awangdarmawan
# maulida
# Marulina Dewi Sinaga
# Wem 91
# Syaifullbakr1 Drajat
# ichwan Setiarahman
# Dhimas Pangestu
# Irvan Mubarock
# udevkhan
# Muhamad Gunadi
# Seprian Abdi Bermanda
# Love Quotes
# SMA N 1 Gemolong
# alpinestars
# Tyco BMW
# Suzuki Racing
# Team Suzuki Racing
# RemusExhaustUSA
# DENSO Auto Parts
# Valeo Service
# HKS Europe Ltd
# OVERKILL
# Rolling Stone INA
# Bejelit
# Sentul Circuit
# Auto 2000 BSD
# TOYOTA AUTO 2000 BDG
# I Love Bogor
# IG: kuliner_bgr
# Ducati
# Honda Indonesia
# MotoGP™ 🇯🇵
# Yamaha Racing
# WorldSBK
# Crescent
# Mitsubishi USA
# Honda
# android nation
# Tabloid PULSA
# Ecko PowerMetal
# DREAMER
# Ipunk Power Metal
# Helloween
# DragonForce
# Frozen Sand
# Kota Solo
# Rudi Triatmono
# Papanya Anak-anak
# dapurpacu
# Swift Club Indonesia
# Suzuki Jip Indonesia
# GridOto.com
# Bayu Permana
# dwy sanggara
# Raksaka Indra
# julius gigih dimas

# %%
# mengcrawl 10 data tweets kita sendiri
for tweet in tweepy.Cursor(api.user_timeline).items(10):
    print(tweet.text)
# Out:
# View my verified achievement from IBM on Acclaim. https://t.co/KaufDLhi1D
# View my verified achievement from IBM on Acclaim. https://t.co/JzPxCTCpV2
# Semoga gadis yang baik hati,cakeppp+bening, gak sombong, nrima apa adanya, mau diajak berkomitmen, sayang anak,gema… https://t.co/JnXL7LYorU
# Hope everything goes well https://t.co/aUJWEN5VF4
# om telolet om
# RT @raksakaindra: Nasehat Bagi Pemuda-Pemudi Yang Masih Menunda Nikah https://t.co/EGBijIvZJq
# @raksakaindra nasehat yang luar biasa....kwe kpn? 😂
# Selamat ulang tahun kota SOLO ke 271 #0271Solo
# @CBRBogor woyo.....gas brooo....
# Anda - Tentang Seseorang https://t.co/ACnjiCG4yx via @YouTube

# %%
# mengcrawl 5 data tweets dari 'nytimes'
for tweet in api.user_timeline(id="nytimes", count=5):
   print(tweet.text)
# Out:
# 2 separate shootings in Philadelphia over the weekend left a 2-year-old girl dead and an 11-month-old boy in critic… https://t.co/JRnqC0JFpD
# RT @DanaGoldstein: Our piece on Warren education plan: Biggest increase proposed to date in funding for low-income schools (4x current leve…
# Even if wealthy residents move away, the revenue at death from those who stay outweighs any loss in income taxes, n… https://t.co/eBb5XYcX5s
# “If Google doesn’t step up its efforts in the premium hardware market, the low end may become the only place where… https://t.co/QJgwYPfzfu
# Prime Minister Boris Johnson’s Brexit plans ran into yet another roadblock, when John Bercow, the speaker of the Ho… https://t.co/ztYhL9HCwm

# %%
import json

# menampilkan 5 data hasil crawling detikcom ke dalam format JSON
for tweet in api.user_timeline(id="detikcom", count=1):
    print(json.dumps(tweet._json))
# Out:
# {"created_at": "Mon Oct 21 16:04:43 +0000 2019", "id": 1186312367191285760, "id_str": "1186312367191285760", "text": "Presiden Jokowi hari ini memanggil beberapa orang yang bakal menjadi menteri pada periode 2019-2024. Beberapa di an\u2026 https://t.co/x9ADXiyCDX", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/x9ADXiyCDX", "expanded_url": "https://twitter.com/i/web/status/1186312367191285760", "display_url": "twitter.com/i/web/status/1\u2026", "indices": [117, 140]}]}, "source": "<a href=\"https://www.echobox.com\" rel=\"nofollow\">Echobox Social</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 69183155, "id_str": "69183155", "name": "detikcom", "screen_name": "detikcom", "location": "Jakarta, Indonesia", "description": "Official Twitter of https://t.co/oOBkZ1EQMA. redaksi@detik.com | promosi@detik.com | Android: https://t.co/uBAYnisH9r iPhone: https://t.co/36uDqdyxKN", "url": "https://t.co/oOBkZ1EQMA", "entities": {"url": {"urls": [{"url": "https://t.co/oOBkZ1EQMA", "expanded_url": "http://www.detik.com", "display_url": "detik.com", "indices": [0, 23]}]}, "description": {"urls": [{"url": "https://t.co/oOBkZ1EQMA", "expanded_url": "http://www.detik.com", "display_url": "detik.com", "indices": [20, 43]}, {"url": "https://t.co/uBAYnisH9r", "expanded_url": "http://detik.com/android", "display_url": "detik.com/android", "indices": [94, 117]}, {"url": "https://t.co/36uDqdyxKN", "expanded_url": "http://detik.com/iphone", "display_url": "detik.com/iphone", "indices": [126, 149]}]}}, "protected": false, "followers_count": 15440326, "friends_count": 28, "listed_count": 13236, "created_at": "Thu Aug 27 03:03:05 +0000 2009", "favourites_count": 35, "utc_offset": null, "time_zone": null, "geo_enabled": true, "verified": true, "statuses_count": 1550274, "lang": null, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "EDECE9", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1164051844634533889/Guwsnm3w_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1164051844634533889/Guwsnm3w_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/69183155/1566366688", "profile_link_color": "088253", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "E3E2DE", "profile_text_color": "634047", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": false, "follow_request_sent": false, "notifications": false, "translator_type": "regular"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 4, "favorite_count": 6, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "in"}

# %%
# mengambil tweets dengan taggar tertentu dg search, dicontoh kita meng crawling tagar #bigdata

for tweet in tweepy.Cursor(api.search,q="#bigdata",
                           lang="en",
                           since="2019-01-01").items(10):
    print(tweet.text)
# Out:
# RT @YSoft: Edge Computing [#Infographic]
# MT @MikeQuindazzi 70% of #data will stay on the edge, fueling the growth of #EdgeComputing through…
# RT @MikeQuindazzi: #AI is now reading better than humans &gt;&gt;&gt; HT @TopCyberNews and @wef via @MikeQuindazzi &gt;&gt;&gt; #IoT #NLP #CloudComputing #Bi…
# RT @jrzaranoid: #3D #camera #Revolution that gives #vision to the #visually #challenged
#
# #healthcare #HealthAndWellness #HealthyLiving #hea…
# RT @govtechnews SFO Launches #SFWiFi in 32 public spaces https://t.co/adkFsSqTPk @SFCityCIO #BigData #privacy https://t.co/KA20sCr48Z
# RT @MER4BetterIG: GROWTH!
# You are the same person 10 years from now if not for the:
#   - People you meet
#   - Books you read
#   - Experiences…
# RT @R_Demidchuk: Many companies have #BigData &amp; #Analytics teams to obtain the best analysis of existing data. What are the skills and role…
# #3D #camera #Revolution that gives #vision to the #visually #challenged
#
# #healthcare #HealthAndWellness… https://t.co/4hJZw6sDEv
# RT @KirkDBorne: P-Value Explained in One Picture: https://t.co/aG0d9k53Vb #abdsc
# —————
# #BigData #DataScience #StatisticalLiteracy #Statist…
# RT @R_Demidchuk: Many companies have #BigData &amp; #Analytics teams to obtain the best analysis of existing data. What are the skills and role…
# Business intelligence vs. traditional reporting: what are the key differences? Find out their best features and lea… https://t.co/8Ew0slSXn5

# %%
# mengambil item tertentu dari JSON tweets ke list
tweets_data = []
for tweet in tweepy.Cursor(api.search,q="#bigdata",
                           lang="en",
                           since="2019-01-01").items(5):
    tweets_data.append([tweet.author.screen_name,
                        tweet.lang,
                        tweet.created_at,
                        tweet.favorite_count,
                        tweet.retweet_count,
                        tweet.text,
                        tweet.user.location])
print(tweets_data)
# Out:
# [['MixIntelligence', 'en', datetime.datetime(2019, 10, 21, 16, 7, 27), 0, 1, 'RT @YSoft: Edge Computing [#Infographic]\nMT @MikeQuindazzi 70% of #data will stay on the edge, fueling the growth of #EdgeComputing through…', 'United States'], ['mary_b_68', 'en', datetime.datetime(2019, 10, 21, 16, 7, 16), 0, 138, 'RT @MikeQuindazzi: #AI is now reading better than humans &gt;&gt;&gt; HT @TopCyberNews and @wef via @MikeQuindazzi &gt;&gt;&gt; #IoT #NLP #CloudComputing #Bi…', 'Monterrey, Nuevo León'], ['MarkJen77446668', 'en', datetime.datetime(2019, 10, 21, 16, 3, 15), 0, 1, 'RT @jrzaranoid: #3D #camera #Revolution that gives #vision to the #visually #challenged\n\n#healthcare #HealthAndWellness #HealthyLiving #hea…', ''], ['KryptonBrothers', 'en', datetime.datetime(2019, 10, 21, 16, 2, 35), 0, 0, 'RT @govtechnews SFO Launches #SFWiFi in 32 public spaces https://t.co/adkFsSqTPk @SFCityCIO #BigData #privacy https://t.co/KA20sCr48Z', 'Greater Metro NYC'], ['JustBeMentalist', 'en', datetime.datetime(2019, 10, 21, 16, 2, 9), 0, 1, 'RT @MER4BetterIG: GROWTH!\nYou are the same person 10 years from now if not for the:\n  - People you meet\n  - Books you read\n  - Experiences…', 'Shropshire']]

# %%
# convert list to Dataframe
import pandas as pd
tweets_pd = pd.DataFrame(tweets_data,
                         columns=['author.screen_name', 'lang', 'created_at', 'fav_count', 'retweet_count', 'text', 'user.location'])
display(tweets_pd)
# Out:
#   author.screen_name lang          created_at  fav_count  retweet_count  \
# 0    MixIntelligence   en 2019-10-21 16:07:27          0              1
# 1          mary_b_68   en 2019-10-21 16:07:16          0            138
# 2    MarkJen77446668   en 2019-10-21 16:03:15          0              1
# 3    KryptonBrothers   en 2019-10-21 16:02:35          0              0
# 4    JustBeMentalist   en 2019-10-21 16:02:09          0              1
#
#                                                 text          user.location
# 0  RT @YSoft: Edge Computing [#Infographic]\nMT @...          United States
# 1  RT @MikeQuindazzi: #AI is now reading better t...  Monterrey, Nuevo León
# 2  RT @jrzaranoid: #3D #camera #Revolution that g...
# 3  RT @govtechnews SFO Launches #SFWiFi in 32 pub...      Greater Metro NYC
# 4  RT @MER4BetterIG: GROWTH!\nYou are the same pe...             Shropshire

# %%
# mengkonversi dataframe ke file csv
bytes_to_write = tweets_pd.to_csv(index = None, header=True).encode()

# letakkan file csv ke bucket S3
import s3fs
s3 = s3fs.S3FileSystem()

with s3.open('rosihanari/data_twitter.csv', 'wb') as f:
    f.write(bytes_to_write)

# %%
# mengambil data streaming dari twitter dari keyword tertentu
# data stream dibaca dalam format JSON dan langsung disimpan di Amazon S3

import tweepy
import json
from tweepy.streaming import StreamListener
import s3fs
s3 = s3fs.S3FileSystem()

json_temp = []

class MyStreamListener(tweepy.StreamListener):
    
    def __init__(self, api=None):
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0

    def on_status(self, tweet):
        
        # membatasi jumlah data streaming tweets (n = 5)
        self.num_tweets += 1
        if self.num_tweets < 5:
            # mencetak text status hasil streaming
            print(tweet.text)
            json_temp.append(tweet._json)
            # menyimpan setiap JSON hasil streaming ke S3
            with s3.open('rosihanari/data_twitter_json.json', 'ab') as f:
                f.write(json.dumps(json_temp).encode('utf-8'))
            return True
        else:
            return False

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# streaming keyword='python'
myStream.filter(track=['python'])
